# %%
import pandas as pd

# %% [markdown]
# # a

# %%
dataa = pd.read_csv("Cars.csv")
dataa
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean, cov = [0, 0], [(1, .6), (.6, 1)]
x, y = np.random.multivariate_normal(mean, cov, 100).T
y += x + 1

f, ax = plt.subplots(figsize=(6,6))

ax.scatter(x,y, c="red")
ax.set(xlim=(-3,3),ylim=(-3,3))

#draw diagonal
diag_line, = ax.plot(ax.get_xlim(), ax.get_ylim(), ls = "--", c = "blue")

def on_change(axes):
    x_lims = ax.get_xlim()
    y_lims = ax.get_ylim()
    diag_line.set_data(x_lims,y_lims) 


#connects callbacks to your axes

ax.callbacks.connect("xlim_changed", on_change)
ax.callbacks.connect("ylim_changed", on_change)

plt.show()

# %%
import statsmodels.api as sm
sm.qqplot(dataa['MPG'])
plt.xlabel('MPG', color ='red')
plt.savefig('MPG of cars.png')
plt.show()

# %%
import scipy.stats as stats
stats.probplot(dataa['MPG'], dist="norm", plot=plt)
plt.xlabel('MPG', color ='red')
plt.savefig('MPG of cars.png')
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(dataa['MPG'],kde=True, bins =10)
plt.show()
# Out:
# C:\Users\Akky\AppData\Local\Temp\ipykernel_23896\3091900876.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataa['MPG'],kde=True, bins =10)

# %% [markdown]
# MPG of cars follows normal distribution

# %% [markdown]
# # b

# %%
datab = pd.read_csv(r"wc-at.csv")
datab
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
sm.qqplot(datab['Waist'])
plt.show()

# %%
stats.probplot(datab['Waist'], dist = 'norm', plot = plt)
plt.xlabel('Waist', color= 'red')
plt.show()

# %%
sns.distplot(datab['Waist'],  bins=10, kde = True)
plt.show()
# Out:
# C:\Users\Akky\AppData\Local\Temp\ipykernel_23896\690004643.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(datab['Waist'],  bins=10, kde = True)

# %%
sm.qqplot(datab['AT'])
plt.show()

# %%
stats.probplot(datab['AT'], dist = 'norm', plot = plt)
plt.xlabel('AT', color= 'red')
plt.show()

# %%
sns.distplot(datab['AT'], bins =10, kde=True)
plt.show()
# Out:
# C:\Users\Akky\AppData\Local\Temp\ipykernel_23896\870664887.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(datab['AT'], bins =10, kde=True)

# %% [markdown]
# Adipose Tissue (AT) and Waist does not follow Normal Distribution
